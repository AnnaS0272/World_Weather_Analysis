# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 615

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=aa464e3b066490e2012094930cddf430

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        try:    
            city_weather_desc = city_weather["weather"][0]["description"]
        except:
            city_weather_desc = "No description"
        try:
            city_rain = city_weather["rain"]["1h"]
        except:
            city_rain = 0
        try:
            city_snow = city_weather["snow"]["1h"]
        except:
            city_snow = 0  
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc,
                          "Rain (Inches)": city_rain,
                          "Snow (Inches)": city_snow
                          })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiruchchendur
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | college
# Processing Record 5 of Set 1 | bulawayo
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | sterling
# Processing Record 8 of Set 1 | katsuura
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | barrow
# Processing Record 12 of Set 1 | puerto ayora
# Processing Record 13 of Set 1 | trelew
# Processing Record 14 of Set 1 | werder
# Processing Record 15 of Set 1 | codrington
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 1 | mairana
# Processing Record 21 of Set 1 | kuhestan
# City not found. Skipping...
# Processing Record 22 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 23 of Set 1 | oriximina
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | kodiak
# Processing Record 27 of Set 1 | moriyama
# Processing Record 28 of Set 1 | clyde river
# Processing Record 29 of Set 1 | olafsvik
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | nam tha
# City not found. Skipping...
# Processing Record 32 of Set 1 | antofagasta
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 1 | palmer
# Processing Record 37 of Set 1 | vardo
# Processing Record 38 of Set 1 | rikitea
# Processing Record 39 of Set 1 | laguna
# Processing Record 40 of Set 1 | mahebourg
# Processing Record 41 of Set 1 | xiaoweizhai
# Processing Record 42 of Set 1 | kitimat
# Processing Record 43 of Set 1 | severo-kurilsk
# Processing Record 44 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 1 | sinnamary
# Processing Record 47 of Set 1 | santa lucia
# Processing Record 48 of Set 1 | lagoa
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | ribeira grande
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | gat
# Processing Record 3 of Set 2 | butaritari
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 7 of Set 2 | goundam
# Processing Record 8 of Set 2 | assela
# City not found. Skipping...
# Processing Record 9 of Set 2 | port blair
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | tuktoyaktuk
# Processing Record 13 of Set 2 | santa rosa
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | naftah
# City not found. Skipping...
# Processing Record 16 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 17 of Set 2 | oktyabrskoye
# Processing Record 18 of Set 2 | pran buri
# Processing Record 19 of Set 2 | kyzyl-suu
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | mahibadhoo
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | klyuchi
# Processing Record 24 of Set 2 | kibray
# Processing Record 25 of Set 2 | constitucion
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | barcelos
# Processing Record 28 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 2 | hovd
# Processing Record 31 of Set 2 | aquiraz
# Processing Record 32 of Set 2 | hobyo
# Processing Record 33 of Set 2 | beringovskiy
# Processing Record 34 of Set 2 | lata
# Processing Record 35 of Set 2 | mangrol
# Processing Record 36 of Set 2 | richards bay
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | ulladulla
# Processing Record 39 of Set 2 | sola
# Processing Record 40 of Set 2 | hamilton
# Processing Record 41 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 42 of Set 2 | rincon
# Processing Record 43 of Set 2 | simbahan
# Processing Record 44 of Set 2 | chuy
# Processing Record 45 of Set 2 | taoudenni
# Processing Record 46 of Set 2 | bad orb
# Processing Record 47 of Set 2 | kampot
# Processing Record 48 of Set 2 | chokurdakh
# Processing Record 49 of Set 2 | pierre
# Processing Record 50 of Set 2 | albany
# Processing Record 1 of Set 3 | pokrovka
# Processing Record 2 of Set 3 | hasaki
# Processing Record 3 of Set 3 | naze
# Processing Record 4 of Set 3 | tazovskiy
# Processing Record 5 of Set 3 | saint-joseph
# Processing Record 6 of Set 3 | khovu-aksy
# Processing Record 7 of Set 3 | jacmel
# Processing Record 8 of Set 3 | khatanga
# Processing Record 9 of Set 3 | aitape
# Processing Record 10 of Set 3 | kembolcha
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | east london
# Processing Record 13 of Set 3 | ewa beach
# Processing Record 14 of Set 3 | arman
# Processing Record 15 of Set 3 | leningradskiy
# Processing Record 16 of Set 3 | channel-port aux basques
# Processing Record 17 of Set 3 | twin falls
# Processing Record 18 of Set 3 | raudeberg
# Processing Record 19 of Set 3 | dingle
# Processing Record 20 of Set 3 | fairbanks
# Processing Record 21 of Set 3 | ambanja
# Processing Record 22 of Set 3 | zhigansk
# Processing Record 23 of Set 3 | erzin
# Processing Record 24 of Set 3 | paamiut
# Processing Record 25 of Set 3 | anzio
# Processing Record 26 of Set 3 | hermanus
# Processing Record 27 of Set 3 | lebu
# Processing Record 28 of Set 3 | yar-sale
# Processing Record 29 of Set 3 | weinan
# Processing Record 30 of Set 3 | gawler
# Processing Record 31 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 3 | mae sai
# Processing Record 33 of Set 3 | magnor
# Processing Record 34 of Set 3 | chabahar
# Processing Record 35 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 36 of Set 3 | vierzon
# Processing Record 37 of Set 3 | millet
# Processing Record 38 of Set 3 | benguela
# Processing Record 39 of Set 3 | pascagoula
# Processing Record 40 of Set 3 | raymond terrace
# Processing Record 41 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 42 of Set 3 | iqaluit
# Processing Record 43 of Set 3 | banda aceh
# Processing Record 44 of Set 3 | thompson
# Processing Record 45 of Set 3 | alofi
# Processing Record 46 of Set 3 | san andres
# Processing Record 47 of Set 3 | cherskiy
# Processing Record 48 of Set 3 | shimoda
# Processing Record 49 of Set 3 | northam
# Processing Record 50 of Set 3 | diapaga
# Processing Record 1 of Set 4 | pangai
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 4 | phan thiet
# Processing Record 5 of Set 4 | sao felix do xingu
# Processing Record 6 of Set 4 | bengkulu
# Processing Record 7 of Set 4 | geraldton
# Processing Record 8 of Set 4 | nyurba
# Processing Record 9 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 4 | burns lake
# Processing Record 11 of Set 4 | belmonte
# Processing Record 12 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 13 of Set 4 | isangel
# Processing Record 14 of Set 4 | provideniya
# Processing Record 15 of Set 4 | dudinka
# Processing Record 16 of Set 4 | barabinsk
# Processing Record 17 of Set 4 | quang ngai
# Processing Record 18 of Set 4 | puerto palomas
# Processing Record 19 of Set 4 | yenagoa
# Processing Record 20 of Set 4 | marzuq
# Processing Record 21 of Set 4 | foam lake
# Processing Record 22 of Set 4 | longyearbyen
# Processing Record 23 of Set 4 | margate
# Processing Record 24 of Set 4 | dikson
# Processing Record 25 of Set 4 | saint-philippe
# Processing Record 26 of Set 4 | haines junction
# Processing Record 27 of Set 4 | erenhot
# Processing Record 28 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 4 | coquimbo
# Processing Record 30 of Set 4 | porto tolle
# Processing Record 31 of Set 4 | mount isa
# Processing Record 32 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 4 | ballina
# Processing Record 34 of Set 4 | nsanje
# Processing Record 35 of Set 4 | bulungu
# Processing Record 36 of Set 4 | mayor pablo lagerenza
# Processing Record 37 of Set 4 | loandjili
# Processing Record 38 of Set 4 | shetpe
# Processing Record 39 of Set 4 | kalmar
# Processing Record 40 of Set 4 | rio real
# Processing Record 41 of Set 4 | murchison
# Processing Record 42 of Set 4 | kupiskis
# Processing Record 43 of Set 4 | los llanos de aridane
# Processing Record 44 of Set 4 | zhanakorgan
# Processing Record 45 of Set 4 | saint george
# Processing Record 46 of Set 4 | cedar falls
# Processing Record 47 of Set 4 | kon tum
# Processing Record 48 of Set 4 | sorkjosen
# Processing Record 49 of Set 4 | tucson
# Processing Record 50 of Set 4 | baoding
# Processing Record 1 of Set 5 | kingsville
# Processing Record 2 of Set 5 | cidreira
# Processing Record 3 of Set 5 | hithadhoo
# Processing Record 4 of Set 5 | celestun
# Processing Record 5 of Set 5 | port elizabeth
# Processing Record 6 of Set 5 | ayan
# Processing Record 7 of Set 5 | bandarbeyla
# Processing Record 8 of Set 5 | aykhal
# Processing Record 9 of Set 5 | mikuni
# Processing Record 10 of Set 5 | mato verde
# Processing Record 11 of Set 5 | namibe
# Processing Record 12 of Set 5 | gull lake
# Processing Record 13 of Set 5 | inhambane
# Processing Record 14 of Set 5 | birao
# Processing Record 15 of Set 5 | lavrentiya
# Processing Record 16 of Set 5 | upernavik
# Processing Record 17 of Set 5 | bilibino
# Processing Record 18 of Set 5 | eslov
# Processing Record 19 of Set 5 | aklavik
# Processing Record 20 of Set 5 | bantry
# Processing Record 21 of Set 5 | audru
# Processing Record 22 of Set 5 | mareeba
# Processing Record 23 of Set 5 | avera
# Processing Record 24 of Set 5 | nelson
# Processing Record 25 of Set 5 | cockburn town
# Processing Record 26 of Set 5 | yunjinghong
# City not found. Skipping...
# Processing Record 27 of Set 5 | muli
# Processing Record 28 of Set 5 | malanville
# Processing Record 29 of Set 5 | mar del plata
# Processing Record 30 of Set 5 | tasiilaq
# Processing Record 31 of Set 5 | ponta do sol
# Processing Record 32 of Set 5 | nanortalik
# Processing Record 33 of Set 5 | caravelas
# Processing Record 34 of Set 5 | amga
# Processing Record 35 of Set 5 | kita
# Processing Record 36 of Set 5 | sakakah
# Processing Record 37 of Set 5 | hoorn
# Processing Record 38 of Set 5 | bouza
# Processing Record 39 of Set 5 | rocha
# Processing Record 40 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 5 | kourou
# Processing Record 42 of Set 5 | pisco
# Processing Record 43 of Set 5 | chaman
# Processing Record 44 of Set 5 | hornepayne
# Processing Record 45 of Set 5 | gizo
# Processing Record 46 of Set 5 | pevek
# Processing Record 47 of Set 5 | mecca
# Processing Record 48 of Set 5 | san cristobal
# Processing Record 49 of Set 5 | ibra
# Processing Record 50 of Set 5 | yulara
# Processing Record 1 of Set 6 | itaituba
# Processing Record 2 of Set 6 | bytow
# Processing Record 3 of Set 6 | kruisfontein
# Processing Record 4 of Set 6 | lucea
# Processing Record 5 of Set 6 | westport
# Processing Record 6 of Set 6 | kahului
# Processing Record 7 of Set 6 | kaitangata
# Processing Record 8 of Set 6 | atambua
# Processing Record 9 of Set 6 | gamba
# Processing Record 10 of Set 6 | dakar
# Processing Record 11 of Set 6 | saldanha
# Processing Record 12 of Set 6 | aloleng
# Processing Record 13 of Set 6 | amapa
# Processing Record 14 of Set 6 | udachnyy
# Processing Record 15 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 6 | umea
# Processing Record 17 of Set 6 | sicuani
# Processing Record 18 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 6 | hirara
# Processing Record 20 of Set 6 | san patricio
# Processing Record 21 of Set 6 | kautokeino
# Processing Record 22 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 6 | lokosovo
# Processing Record 24 of Set 6 | prescott
# Processing Record 25 of Set 6 | yima
# Processing Record 26 of Set 6 | sisimiut
# Processing Record 27 of Set 6 | meulaboh
# Processing Record 28 of Set 6 | makakilo city
# Processing Record 29 of Set 6 | harer
# Processing Record 30 of Set 6 | wexford
# Processing Record 31 of Set 6 | kavieng
# Processing Record 32 of Set 6 | yuanping
# Processing Record 33 of Set 6 | ancud
# Processing Record 34 of Set 6 | duki
# Processing Record 35 of Set 6 | sigli
# Processing Record 36 of Set 6 | ambilobe
# Processing Record 37 of Set 6 | eenhana
# Processing Record 38 of Set 6 | leh
# Processing Record 39 of Set 6 | altamont
# Processing Record 40 of Set 6 | kiruna
# Processing Record 41 of Set 6 | tocopilla
# Processing Record 42 of Set 6 | daru
# Processing Record 43 of Set 6 | narsaq
# Processing Record 44 of Set 6 | roma
# Processing Record 45 of Set 6 | oistins
# Processing Record 46 of Set 6 | faya
# Processing Record 47 of Set 6 | smoky lake
# Processing Record 48 of Set 6 | norman wells
# Processing Record 49 of Set 6 | baykit
# Processing Record 50 of Set 6 | kaohsiung
# Processing Record 1 of Set 7 | talnakh
# Processing Record 2 of Set 7 | acari
# Processing Record 3 of Set 7 | tabuk
# Processing Record 4 of Set 7 | gualaquiza
# Processing Record 5 of Set 7 | san juan
# Processing Record 6 of Set 7 | huarmey
# Processing Record 7 of Set 7 | ilulissat
# Processing Record 8 of Set 7 | ahipara
# Processing Record 9 of Set 7 | punta alta
# Processing Record 10 of Set 7 | hillsborough
# Processing Record 11 of Set 7 | puerto escondido
# Processing Record 12 of Set 7 | homer
# Processing Record 13 of Set 7 | sorland
# Processing Record 14 of Set 7 | coihaique
# Processing Record 15 of Set 7 | shurugwi
# Processing Record 16 of Set 7 | victoria
# Processing Record 17 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 7 | bailen
# Processing Record 19 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 20 of Set 7 | vila velha
# Processing Record 21 of Set 7 | asfi
# Processing Record 22 of Set 7 | nganjuk
# Processing Record 23 of Set 7 | arona
# Processing Record 24 of Set 7 | bethel
# Processing Record 25 of Set 7 | sept-iles
# Processing Record 26 of Set 7 | bud
# Processing Record 27 of Set 7 | lima
# Processing Record 28 of Set 7 | mayo
# Processing Record 29 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 7 | ixtapa
# Processing Record 31 of Set 7 | ariquemes
# Processing Record 32 of Set 7 | esperance
# Processing Record 33 of Set 7 | aripuana
# Processing Record 34 of Set 7 | acarau
# Processing Record 35 of Set 7 | alibag
# Processing Record 36 of Set 7 | igarka
# Processing Record 37 of Set 7 | barao de melgaco
# Processing Record 38 of Set 7 | balatonszarszo
# Processing Record 39 of Set 7 | gornopravdinsk
# Processing Record 40 of Set 7 | sao filipe
# Processing Record 41 of Set 7 | talaya
# Processing Record 42 of Set 7 | plettenberg bay
# Processing Record 43 of Set 7 | houma
# Processing Record 44 of Set 7 | dutlwe
# Processing Record 45 of Set 7 | kailua
# Processing Record 46 of Set 7 | faanui
# Processing Record 47 of Set 7 | urengoy
# Processing Record 48 of Set 7 | jackson
# Processing Record 49 of Set 7 | tonder
# Processing Record 50 of Set 7 | abasha
# Processing Record 1 of Set 8 | catamarca
# Processing Record 2 of Set 8 | quatre cocos
# Processing Record 3 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 8 | nemea
# Processing Record 5 of Set 8 | port-cartier
# Processing Record 6 of Set 8 | krasnoarmeysk
# Processing Record 7 of Set 8 | waingapu
# Processing Record 8 of Set 8 | qasigiannguit
# Processing Record 9 of Set 8 | kuito
# Processing Record 10 of Set 8 | lincoln
# Processing Record 11 of Set 8 | cody
# Processing Record 12 of Set 8 | vallenar
# Processing Record 13 of Set 8 | vila franca do campo
# Processing Record 14 of Set 8 | safaga
# Processing Record 15 of Set 8 | lompoc
# Processing Record 16 of Set 8 | nelson bay
# Processing Record 17 of Set 8 | srednekolymsk
# Processing Record 18 of Set 8 | wanaka
# Processing Record 19 of Set 8 | kununurra
# Processing Record 20 of Set 8 | haverfordwest
# Processing Record 21 of Set 8 | bugama
# Processing Record 22 of Set 8 | inuvik
# Processing Record 23 of Set 8 | toora-khem
# Processing Record 24 of Set 8 | mackenzie
# Processing Record 25 of Set 8 | sitka
# Processing Record 26 of Set 8 | nalut
# Processing Record 27 of Set 8 | eyl
# Processing Record 28 of Set 8 | hofn
# Processing Record 29 of Set 8 | skjervoy
# Processing Record 30 of Set 8 | biak
# Processing Record 31 of Set 8 | nizhniy odes
# Processing Record 32 of Set 8 | toftir
# City not found. Skipping...
# Processing Record 33 of Set 8 | bagdarin
# Processing Record 34 of Set 8 | disna
# Processing Record 35 of Set 8 | ivajlovgrad
# City not found. Skipping...
# Processing Record 36 of Set 8 | goteborg
# City not found. Skipping...
# Processing Record 37 of Set 8 | grevesmuhlen
# Processing Record 38 of Set 8 | zoutleeuw
# Processing Record 39 of Set 8 | mayumba
# Processing Record 40 of Set 8 | roebourne
# Processing Record 41 of Set 8 | cururupu
# Processing Record 42 of Set 8 | cabatuan
# Processing Record 43 of Set 8 | karamay
# City not found. Skipping...
# Processing Record 44 of Set 8 | taganak
# Processing Record 45 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 46 of Set 8 | okhotsk
# Processing Record 47 of Set 8 | tamandare
# Processing Record 48 of Set 8 | kuytun
# Processing Record 49 of Set 8 | saint marys
# Processing Record 50 of Set 8 | carnarvon
# Processing Record 1 of Set 9 | valparaiso
# Processing Record 2 of Set 9 | kundiawa
# Processing Record 3 of Set 9 | high river
# Processing Record 4 of Set 9 | yemelyanovo
# Processing Record 5 of Set 9 | te anau
# Processing Record 6 of Set 9 | kefalos
# Processing Record 7 of Set 9 | liberia
# Processing Record 8 of Set 9 | tuatapere
# Processing Record 9 of Set 9 | ormara
# Processing Record 10 of Set 9 | bardiyah
# Processing Record 11 of Set 9 | bolobo
# Processing Record 12 of Set 9 | wagar
# Processing Record 13 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 9 | luwuk
# Processing Record 16 of Set 9 | elizabeth city
# Processing Record 17 of Set 9 | waipawa
# Processing Record 18 of Set 9 | turukhansk
# Processing Record 19 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 20 of Set 9 | saint stephen
# Processing Record 21 of Set 9 | vanimo
# Processing Record 22 of Set 9 | zheleznodorozhnyy
# Processing Record 23 of Set 9 | huayucachi
# Processing Record 24 of Set 9 | port hawkesbury
# Processing Record 25 of Set 9 | devils lake
# Processing Record 26 of Set 9 | gurskoye
# City not found. Skipping...
# Processing Record 27 of Set 9 | bonfim
# Processing Record 28 of Set 9 | hastings
# Processing Record 29 of Set 9 | bambous virieux
# Processing Record 30 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 31 of Set 9 | jardim
# Processing Record 32 of Set 9 | stuttgart
# Processing Record 33 of Set 9 | cayenne
# Processing Record 34 of Set 9 | nishihara
# Processing Record 35 of Set 9 | yumen
# Processing Record 36 of Set 9 | luderitz
# Processing Record 37 of Set 9 | pokrovskoye
# Processing Record 38 of Set 9 | roald
# Processing Record 39 of Set 9 | maumelle
# Processing Record 40 of Set 9 | port lincoln
# Processing Record 41 of Set 9 | naryan-mar
# Processing Record 42 of Set 9 | san jeronimo
# Processing Record 43 of Set 9 | mogadishu
# Processing Record 44 of Set 9 | noumea
# Processing Record 45 of Set 9 | shahreza
# Processing Record 46 of Set 9 | beloha
# Processing Record 47 of Set 9 | ahumada
# City not found. Skipping...
# Processing Record 48 of Set 9 | kavaratti
# Processing Record 49 of Set 9 | krasnoselkup
# Processing Record 50 of Set 9 | vila
# Processing Record 1 of Set 10 | mount gambier
# Processing Record 2 of Set 10 | buraydah
# Processing Record 3 of Set 10 | lichinga
# Processing Record 4 of Set 10 | tibiao
# Processing Record 5 of Set 10 | ankazoabo
# Processing Record 6 of Set 10 | poum
# Processing Record 7 of Set 10 | cuajinicuilapa
# Processing Record 8 of Set 10 | airai
# Processing Record 9 of Set 10 | gorontalo
# Processing Record 10 of Set 10 | san gabriel
# Processing Record 11 of Set 10 | nosy varika
# Processing Record 12 of Set 10 | kaspiysk
# Processing Record 13 of Set 10 | linjiang
# Processing Record 14 of Set 10 | jian
# Processing Record 15 of Set 10 | nacajuca
# Processing Record 16 of Set 10 | salalah
# Processing Record 17 of Set 10 | nuuk
# Processing Record 18 of Set 10 | malakal
# Processing Record 19 of Set 10 | kempen
# Processing Record 20 of Set 10 | alice springs
# Processing Record 21 of Set 10 | anadyr
# Processing Record 22 of Set 10 | tessalit
# Processing Record 23 of Set 10 | bousse
# Processing Record 24 of Set 10 | hohhot
# Processing Record 25 of Set 10 | newport
# Processing Record 26 of Set 10 | puerto ayacucho
# Processing Record 27 of Set 10 | san ignacio
# Processing Record 28 of Set 10 | labuhan
# Processing Record 29 of Set 10 | de-kastri
# Processing Record 30 of Set 10 | teguldet
# Processing Record 31 of Set 10 | klaksvik
# Processing Record 32 of Set 10 | lubango
# Processing Record 33 of Set 10 | lieksa
# Processing Record 34 of Set 10 | ostrovnoy
# Processing Record 35 of Set 10 | barstow
# Processing Record 36 of Set 10 | burica
# City not found. Skipping...
# Processing Record 37 of Set 10 | the valley
# Processing Record 38 of Set 10 | kasulu
# Processing Record 39 of Set 10 | usinsk
# Processing Record 40 of Set 10 | matara
# Processing Record 41 of Set 10 | kerki
# City not found. Skipping...
# Processing Record 42 of Set 10 | constantine
# Processing Record 43 of Set 10 | jiangyou
# Processing Record 44 of Set 10 | namatanai
# Processing Record 45 of Set 10 | grand gaube
# Processing Record 46 of Set 10 | kabompo
# Processing Record 47 of Set 10 | necochea
# Processing Record 48 of Set 10 | conde
# Processing Record 49 of Set 10 | katav-ivanovsk
# Processing Record 50 of Set 10 | kamiiso
# Processing Record 1 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 11 | pasir gudang
# Processing Record 3 of Set 11 | hambantota
# Processing Record 4 of Set 11 | dwarka
# Processing Record 5 of Set 11 | miraflores
# Processing Record 6 of Set 11 | tomaszow mazowiecki
# Processing Record 7 of Set 11 | manassas
# Processing Record 8 of Set 11 | nogliki
# Processing Record 9 of Set 11 | monrovia
# Processing Record 10 of Set 11 | tahoua
# Processing Record 11 of Set 11 | jacareacanga
# Processing Record 12 of Set 11 | jalu
# Processing Record 13 of Set 11 | fortuna
# Processing Record 14 of Set 11 | sambava
# Processing Record 15 of Set 11 | sechura
# Processing Record 16 of Set 11 | chipinge
# Processing Record 17 of Set 11 | cabo san lucas
# Processing Record 18 of Set 11 | gambo
# Processing Record 19 of Set 11 | soyo
# Processing Record 20 of Set 11 | trincomalee
# Processing Record 21 of Set 11 | roros
# Processing Record 22 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 23 of Set 11 | kimbe
# Processing Record 24 of Set 11 | sur
# Processing Record 25 of Set 11 | kang
# Processing Record 26 of Set 11 | itoman
# Processing Record 27 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 28 of Set 11 | makhachkala
# Processing Record 29 of Set 11 | madang
# Processing Record 30 of Set 11 | cabra
# Processing Record 31 of Set 11 | ca mau
# Processing Record 32 of Set 11 | barra
# Processing Record 33 of Set 11 | myaundzha
# Processing Record 34 of Set 11 | natchitoches
# Processing Record 35 of Set 11 | ibirapitanga
# Processing Record 36 of Set 11 | antsohihy
# Processing Record 37 of Set 11 | teya
# Processing Record 38 of Set 11 | marsa matruh
# Processing Record 39 of Set 11 | mocuba
# Processing Record 40 of Set 11 | honiara
# Processing Record 41 of Set 11 | kangasala
# Processing Record 42 of Set 11 | portland
# Processing Record 43 of Set 11 | yeppoon
# Processing Record 44 of Set 11 | hokitika
# Processing Record 45 of Set 11 | port hardy
# Processing Record 46 of Set 11 | cap malheureux
# Processing Record 47 of Set 11 | kamaishi
# Processing Record 48 of Set 11 | zeya
# Processing Record 49 of Set 11 | boende
# Processing Record 50 of Set 11 | boa vista
# Processing Record 1 of Set 12 | gouyave
# Processing Record 2 of Set 12 | mamontovo
# Processing Record 3 of Set 12 | fort dodge
# Processing Record 4 of Set 12 | luxor
# Processing Record 5 of Set 12 | deputatskiy
# Processing Record 6 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 7 of Set 12 | hailar
# Processing Record 8 of Set 12 | flinders
# Processing Record 9 of Set 12 | brae
# Processing Record 10 of Set 12 | santo antonio do ica
# Processing Record 11 of Set 12 | rize
# Processing Record 12 of Set 12 | vieques
# Processing Record 13 of Set 12 | wawa
# Processing Record 14 of Set 12 | okha
# Processing Record 15 of Set 12 | saint-georges
# Processing Record 16 of Set 12 | achisay
# City not found. Skipping...
# Processing Record 17 of Set 12 | pitimbu
# Processing Record 18 of Set 12 | superior
# Processing Record 19 of Set 12 | ngerengere
# Processing Record 20 of Set 12 | rezekne
# Processing Record 21 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 22 of Set 12 | banes
# Processing Record 23 of Set 12 | pilar
# Processing Record 24 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 25 of Set 12 | ketchikan
# Processing Record 26 of Set 12 | el alto
# Processing Record 27 of Set 12 | nemuro
# Processing Record 28 of Set 12 | bonavista
# Processing Record 29 of Set 12 | portarlington
# Processing Record 30 of Set 12 | sinazongwe
# Processing Record 31 of Set 12 | khuzhir
# Processing Record 32 of Set 12 | safford
# Processing Record 33 of Set 12 | ladushkin
# Processing Record 34 of Set 12 | coutances
# Processing Record 35 of Set 12 | pundaguitan
# Processing Record 36 of Set 12 | awjilah
# Processing Record 37 of Set 12 | berlevag
# Processing Record 38 of Set 12 | zyryanka
# Processing Record 39 of Set 12 | wahran
# City not found. Skipping...
# Processing Record 40 of Set 12 | launceston
# Processing Record 41 of Set 12 | bilma
# Processing Record 42 of Set 12 | matehuala
# Processing Record 43 of Set 12 | brookhaven
# Processing Record 44 of Set 12 | batticaloa
# Processing Record 45 of Set 12 | rochegda
# Processing Record 46 of Set 12 | timmins
# Processing Record 47 of Set 12 | balagunan
# Processing Record 48 of Set 12 | dobsice
# Processing Record 49 of Set 12 | katobu
# Processing Record 50 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 1 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 2 of Set 13 | nauta
# Processing Record 3 of Set 13 | cape canaveral
# Processing Record 4 of Set 13 | boulder city
# Processing Record 5 of Set 13 | mendi
# Processing Record 6 of Set 13 | galle
# Processing Record 7 of Set 13 | khandbari
# Processing Record 8 of Set 13 | chapais
# Processing Record 9 of Set 13 | ndola
# Processing Record 10 of Set 13 | fethiye
# Processing Record 11 of Set 13 | berndorf
# Processing Record 12 of Set 13 | nantucket
# Processing Record 13 of Set 13 | halifax
# Processing Record 14 of Set 13 | kysyl-syr
# Processing Record 15 of Set 13 | okakarara
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Tiruchchendur',
#   'Lat': 8.48,
#   'Lng': 78.12,
#   'Max Temp': 81.25,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 12.66,
#   'Country': 'IN',
#   'Current Description': 'moderate rain',
#   'Rain (Inches)': 1.2,
#   'Snow (Inches)': 0},
#  {'City': 'Yellowknife',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Max Temp': 64.4,
#   'Humidity': 45,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Country': 'CA',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'College',
#   'Lat': 64.86,
#   'Lng': -147.8,
#   'Max Temp': 57.99,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 2.42,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Bulawayo',
#   'Lat': -20.15,
#   'Lng': 28.58,
#   'Max Temp': 55.13,
#   'Humidity': 62,
#   'Cloudiness': 48,
#   'Wind Speed': 14.74,
#   'Country': 'ZW',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 41,
#   'Humidity': 75,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'AR',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Sterling',
#   'Lat': 39.01,
#   'Lng': -77.43,
#   'Max Temp': 91.99,
#   'Humidity': 36,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Katsuura',
#   'Lat': 35.13,
#   'Lng': 140.3,
#   'Max Temp': 75.2,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Country': 'JP',
#   'Current Description': 'mist',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Max Temp': 32,
#   'Humidity': 91,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'CL',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Max Temp': 37.4,
#   'Humidity': 86,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Barrow',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Max Temp': 44.6,
#   'Humidity': 70,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Max Temp': 71.01,
#   'Humidity': 89,
#   'Cloudiness': 89,
#   'Wind Speed': 5.01,
#   'Country': 'EC',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Trelew',
#   'Lat': -43.25,
#   'Lng': -65.31,
#   'Max Temp': 47.35,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 15.5,
#   'Country': 'AR',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Werder',
#   'Lat': 52.38,
#   'Lng': 12.93,
#   'Max Temp': 61,
#   'Humidity': 84,
#   'Cloudiness': 88,
#   'Wind Speed': 5.39,
#   'Country': 'DE',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Codrington',
#   'Lat': -38.27,
#   'Lng': 141.97,
#   'Max Temp': 40.21,
#   'Humidity': 91,
#   'Cloudiness': 0,
#   'Wind Speed': 8.66,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Max Temp': 46.4,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.12,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Castro',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Max Temp': 57.97,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.93,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.76,
#   'Snow (Inches)': 0},
#  {'City': 'Mairana',
#   'Lat': -18.12,
#   'Lng': -63.93,
#   'Max Temp': 56.3,
#   'Humidity': 79,
#   'Cloudiness': 56,
#   'Wind Speed': 4.36,
#   'Country': 'BO',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Oriximina',
#   'Lat': -1.77,
#   'Lng': -55.87,
#   'Max Temp': 85.06,
#   'Humidity': 68,
#   'Cloudiness': 54,
#   'Wind Speed': 3.22,
#   'Country': 'BR',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'New Norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Max Temp': 35.01,
#   'Humidity': 93,
#   'Cloudiness': 26,
#   'Wind Speed': 2.62,
#   'Country': 'AU',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Max Temp': 79.54,
#   'Humidity': 77,
#   'Cloudiness': 7,
#   'Wind Speed': 13.65,
#   'Country': 'PF',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Max Temp': 60.8,
#   'Humidity': 63,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Moriyama',
#   'Lat': 35.07,
#   'Lng': 135.98,
#   'Max Temp': 73.99,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.39,
#   'Country': 'JP',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.75,
#   'Snow (Inches)': 0},
#  {'City': 'Clyde River',
#   'Lat': 70.47,
#   'Lng': -68.59,
#   'Max Temp': 37.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 6.93,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Olafsvik',
#   'Lat': 64.89,
#   'Lng': -23.71,
#   'Max Temp': 49.03,
#   'Humidity': 72,
#   'Cloudiness': 9,
#   'Wind Speed': 13.27,
#   'Country': 'IS',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Max Temp': 43,
#   'Humidity': 88,
#   'Cloudiness': 91,
#   'Wind Speed': 6.51,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Antofagasta',
#   'Lat': -23.65,
#   'Lng': -70.4,
#   'Max Temp': 60.8,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Country': 'CL',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'US',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Saskylakh',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Max Temp': 55.44,
#   'Humidity': 70,
#   'Cloudiness': 33,
#   'Wind Speed': 11.18,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Palmer',
#   'Lat': 42.16,
#   'Lng': -72.33,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Country': 'US',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Vardo',
#   'Lat': 70.37,
#   'Lng': 31.11,
#   'Max Temp': 46.4,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'NO',
#   'Current Description': 'light intensity shower rain',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Max Temp': 67.71,
#   'Humidity': 63,
#   'Cloudiness': 12,
#   'Wind Speed': 18.77,
#   'Country': 'PF',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Laguna',
#   'Lat': 38.42,
#   'Lng': -121.42,
#   'Max Temp': 93.99,
#   'Humidity': 24,
#   'Cloudiness': 1,
#   'Wind Speed': 5.55,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Mahebourg',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Max Temp': 71.6,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 12.75,
#   'Country': 'MU',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Xiaoweizhai',
#   'Lat': 26.19,
#   'Lng': 107.51,
#   'Max Temp': 71.37,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Country': 'CN',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.39,
#   'Snow (Inches)': 0},
#  {'City': 'Kitimat',
#   'Lat': 54.05,
#   'Lng': -128.65,
#   'Max Temp': 62.6,
#   'Humidity': 63,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.68,
#   'Lng': 156.12,
#   'Max Temp': 48.02,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 16.17,
#   'Country': 'RU',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.18,
#   'Snow (Inches)': 0},
#  {'City': 'Sinnamary',
#   'Lat': 5.38,
#   'Lng': -52.95,
#   'Max Temp': 80.15,
#   'Humidity': 79,
#   'Cloudiness': 27,
#   'Wind Speed': 6.38,
#   'Country': 'GF',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Santa Lucia',
#   'Lat': 27.91,
#   'Lng': -15.54,
#   'Max Temp': 82.4,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 23.04,
#   'Country': 'ES',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.98,
#   'Max Temp': 68.97,
#   'Humidity': 81,
#   'Cloudiness': 95,
#   'Wind Speed': 7.65,
#   'Country': 'PT',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Qaanaaq',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Max Temp': 47.01,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 2.42,
#   'Country': 'GL',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Max Temp': 69.8,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'PT',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Tiksi',
#   'Lat': 71.69,
#   'Lng': 128.87,
#   'Max Temp': 35.01,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.6,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.76,
#   'Max Temp': 80.01,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind Speed': 6.31,
#   'Country': 'IL',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Butaritari',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Max Temp': 83.12,
#   'Humidity': 77,
#   'Cloudiness': 9,
#   'Wind Speed': 17.76,
#   'Country': 'KI',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Georgetown',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Country': 'MY',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Max Temp': 39,
#   'Humidity': 83,
#   'Cloudiness': 84,
#   'Wind Speed': 3,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Goundam',
#   'Lat': 16.41,
#   'Lng': -3.67,
#   'Max Temp': 100.99,
#   'Humidity': 16,
#   'Cloudiness': 32,
#   'Wind Speed': 10.69,
#   'Country': 'ML',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Port Blair',
#   'Lat': 11.67,
#   'Lng': 92.75,
#   'Max Temp': 80.28,
#   'Humidity': 78,
#   'Cloudiness': 90,
#   'Wind Speed': 5.73,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Cape Town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Max Temp': 57.2,
#   'Humidity': 47,
#   'Cloudiness': 82,
#   'Wind Speed': 3.36,
#   'Country': 'ZA',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Max Temp': 39,
#   'Humidity': 83,
#   'Cloudiness': 69,
#   'Wind Speed': 3,
#   'Country': 'NZ',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Max Temp': 37.4,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Santa Rosa',
#   'Lat': 14.31,
#   'Lng': 121.11,
#   'Max Temp': 81,
#   'Humidity': 80,
#   'Cloudiness': 59,
#   'Wind Speed': 3.8,
#   'Country': 'PH',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Max Temp': 75.2,
#   'Humidity': 69,
#   'Cloudiness': 49,
#   'Wind Speed': 16.11,
#   'Country': 'CK',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Oktyabrskoye',
#   'Lat': 43.06,
#   'Lng': 44.74,
#   'Max Temp': 71.6,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Pran Buri',
#   'Lat': 12.38,
#   'Lng': 99.91,
#   'Max Temp': 77.92,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 5.08,
#   'Country': 'TH',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Kyzyl-Suu',
#   'Lat': 42.34,
#   'Lng': 78,
#   'Max Temp': 61.38,
#   'Humidity': 43,
#   'Cloudiness': 95,
#   'Wind Speed': 4.63,
#   'Country': 'KG',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 73.4,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'TO',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Mahibadhoo',
#   'Lat': 3.78,
#   'Lng': 72.97,
#   'Max Temp': 83.48,
#   'Humidity': 71,
#   'Cloudiness': 58,
#   'Wind Speed': 5.91,
#   'Country': 'MV',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Port Alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Max Temp': 68.14,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 14.07,
#   'Country': 'ZA',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Klyuchi',
#   'Lat': 52.27,
#   'Lng': 79.17,
#   'Max Temp': 63.45,
#   'Humidity': 85,
#   'Cloudiness': 12,
#   'Wind Speed': 6.53,
#   'Country': 'RU',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Kibray',
#   'Lat': 41.39,
#   'Lng': 69.46,
#   'Max Temp': 78.8,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 6.93,
#   'Country': 'UZ',
#   'Current Description': 'smoke',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Constitucion',
#   'Lat': -35.33,
#   'Lng': -72.42,
#   'Max Temp': 51.33,
#   'Humidity': 65,
#   'Cloudiness': 62,
#   'Wind Speed': 6.38,
#   'Country': 'CL',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Max Temp': 77,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Current Description': 'moderate rain',
#   'Rain (Inches)': 1.66,
#   'Snow (Inches)': 0},
#  {'City': 'Barcelos',
#   'Lat': 41.54,
#   'Lng': -8.62,
#   'Max Temp': 70,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 3.36,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Hovd',
#   'Lat': 48.01,
#   'Lng': 91.64,
#   'Max Temp': 58.95,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 4.97,
#   'Country': 'MN',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Aquiraz',
#   'Lat': -3.9,
#   'Lng': -38.39,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 13,
#   'Wind Speed': 16.11,
#   'Country': 'BR',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Hobyo',
#   'Lat': 5.35,
#   'Lng': 48.53,
#   'Max Temp': 78.94,
#   'Humidity': 79,
#   'Cloudiness': 95,
#   'Wind Speed': 28.36,
#   'Country': 'SO',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.32,
#   'Max Temp': 56.88,
#   'Humidity': 63,
#   'Cloudiness': 5,
#   'Wind Speed': 5.37,
#   'Country': 'RU',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Lata',
#   'Lat': 40.16,
#   'Lng': -8.33,
#   'Max Temp': 69.01,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 1.99,
#   'Country': 'PT',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Mangrol',
#   'Lat': 21.12,
#   'Lng': 70.12,
#   'Max Temp': 83.88,
#   'Humidity': 80,
#   'Cloudiness': 21,
#   'Wind Speed': 19.35,
#   'Country': 'IN',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Richards Bay',
#   'Lat': -28.78,
#   'Lng': 32.04,
#   'Max Temp': 61.52,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 10.71,
#   'Country': 'ZA',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Max Temp': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Ulladulla',
#   'Lat': -35.35,
#   'Lng': 150.47,
#   'Max Temp': 45,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Sola',
#   'Lat': -13.88,
#   'Lng': 167.55,
#   'Max Temp': 79.66,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 27.58,
#   'Country': 'VU',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.49,
#   'Snow (Inches)': 0},
#  {'City': 'Hamilton',
#   'Lat': 39.18,
#   'Lng': -84.53,
#   'Max Temp': 95,
#   'Humidity': 55,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Rincon',
#   'Lat': 32.3,
#   'Lng': -81.24,
#   'Max Temp': 89.6,
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.25,
#   'Snow (Inches)': 0},
#  {'City': 'Simbahan',
#   'Lat': 6.3,
#   'Lng': 120.58,
#   'Max Temp': 82.51,
#   'Humidity': 73,
#   'Cloudiness': 91,
#   'Wind Speed': 4.32,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Max Temp': 48.04,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 16.84,
#   'Country': 'UY',
#   'Current Description': 'moderate rain',
#   'Rain (Inches)': 1.2,
#   'Snow (Inches)': 0},
#  {'City': 'Taoudenni',
#   'Lat': 22.68,
#   'Lng': -3.98,
#   'Max Temp': 98.44,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 14.32,
#   'Country': 'ML',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Bad Orb',
#   'Lat': 50.23,
#   'Lng': 9.35,
#   'Max Temp': 59,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.92,
#   'Country': 'DE',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.38,
#   'Snow (Inches)': 0},
#  {'City': 'Kampot',
#   'Lat': 10.62,
#   'Lng': 104.18,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 1.12,
#   'Country': 'KH',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Chokurdakh',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Max Temp': 43.77,
#   'Humidity': 87,
#   'Cloudiness': 96,
#   'Wind Speed': 9.04,
#   'Country': 'RU',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.13,
#   'Snow (Inches)': 0},
#  {'City': 'Pierre',
#   'Lat': 44.37,
#   'Lng': -100.35,
#   'Max Temp': 86,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Max Temp': 82.99,
#   'Humidity': 69,
#   'Cloudiness': 26,
#   'Wind Speed': 5.64,
#   'Country': 'US',
#   'Current Description': 'moderate rain',
#   'Rain (Inches)': 1.52,
#   'Snow (Inches)': 0},
#  {'City': 'Pokrovka',
#   'Lat': 42.34,
#   'Lng': 78.01,
#   'Max Temp': 61.12,
#   'Humidity': 43,
#   'Cloudiness': 95,
#   'Wind Speed': 4.63,
#   'Country': 'KG',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Hasaki',
#   'Lat': 35.73,
#   'Lng': 140.83,
#   'Max Temp': 75,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'JP',
#   'Current Description': 'light intensity shower rain',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Naze',
#   'Lat': 28.37,
#   'Lng': 129.48,
#   'Max Temp': 80.6,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'JP',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Tazovskiy',
#   'Lat': 67.47,
#   'Lng': 78.7,
#   'Max Temp': 50.99,
#   'Humidity': 79,
#   'Cloudiness': 66,
#   'Wind Speed': 15.84,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Saint-Joseph',
#   'Lat': -21.37,
#   'Lng': 55.62,
#   'Max Temp': 68,
#   'Humidity': 68,
#   'Cloudiness': 27,
#   'Wind Speed': 6.93,
#   'Country': 'RE',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Khovu-Aksy',
#   'Lat': 51.13,
#   'Lng': 93.6,
#   'Max Temp': 49.21,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 2.98,
#   'Country': 'RU',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Jacmel',
#   'Lat': 18.23,
#   'Lng': -72.53,
#   'Max Temp': 89.6,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Country': 'HT',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Khatanga',
#   'Lat': 71.97,
#   'Lng': 102.5,
#   'Max Temp': 60.48,
#   'Humidity': 55,
#   'Cloudiness': 4,
#   'Wind Speed': 17.87,
#   'Country': 'RU',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Aitape',
#   'Lat': -3.14,
#   'Lng': 142.35,
#   'Max Temp': 77.18,
#   'Humidity': 84,
#   'Cloudiness': 43,
#   'Wind Speed': 6.13,
#   'Country': 'PG',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Kembolcha',
#   'Lat': 11.08,
#   'Lng': 39.74,
#   'Max Temp': 66.2,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 5.1,
#   'Country': 'ET',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.99,
#   'Snow (Inches)': 0},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Max Temp': 60.8,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'East London',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Max Temp': 67.33,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 13.11,
#   'Country': 'ZA',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Ewa Beach',
#   'Lat': 21.32,
#   'Lng': -158.01,
#   'Max Temp': 84.2,
#   'Humidity': 51,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Country': 'US',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Arman',
#   'Lat': 59.7,
#   'Lng': 150.17,
#   'Max Temp': 50.9,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.32,
#   'Country': 'RU',
#   'Current Description': 'moderate rain',
#   'Rain (Inches)': 1.87,
#   'Snow (Inches)': 0},
#  {'City': 'Leningradskiy',
#   'Lat': 69.38,
#   'Lng': 178.42,
#   'Max Temp': 47.32,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 9.04,
#   'Country': 'RU',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Channel-Port Aux Basques',
#   'Lat': 47.57,
#   'Lng': -59.14,
#   'Max Temp': 59.58,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 14.12,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Twin Falls',
#   'Lat': 42.56,
#   'Lng': -114.46,
#   'Max Temp': 75.2,
#   'Humidity': 29,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Raudeberg',
#   'Lat': 61.99,
#   'Lng': 5.14,
#   'Max Temp': 51.01,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 12.35,
#   'Country': 'NO',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.64,
#   'Snow (Inches)': 0},
#  {'City': 'Dingle',
#   'Lat': 11,
#   'Lng': 122.67,
#   'Max Temp': 77.34,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'PH',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.43,
#   'Snow (Inches)': 0},
#  {'City': 'Fairbanks',
#   'Lat': 64.84,
#   'Lng': -147.72,
#   'Max Temp': 57.99,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Ambanja',
#   'Lat': -13.68,
#   'Lng': 48.45,
#   'Max Temp': 70.41,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 2.98,
#   'Country': 'MG',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Zhigansk',
#   'Lat': 66.77,
#   'Lng': 123.37,
#   'Max Temp': 58.51,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 10.87,
#   'Country': 'RU',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Erzin',
#   'Lat': 36.96,
#   'Lng': 36.2,
#   'Max Temp': 78.01,
#   'Humidity': 81,
#   'Cloudiness': 2,
#   'Wind Speed': 0.4,
#   'Country': 'TR',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Paamiut',
#   'Lat': 61.99,
#   'Lng': -49.67,
#   'Max Temp': 44.01,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 21.41,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Anzio',
#   'Lat': 41.49,
#   'Lng': 12.62,
#   'Max Temp': 75.99,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'IT',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Max Temp': 60.13,
#   'Humidity': 47,
#   'Cloudiness': 87,
#   'Wind Speed': 6.22,
#   'Country': 'ZA',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Lebu',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Max Temp': 49.57,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 9.1,
#   'Country': 'CL',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.19,
#   'Snow (Inches)': 0},
#  {'City': 'Yar-Sale',
#   'Lat': 66.83,
#   'Lng': 70.83,
#   'Max Temp': 53.24,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 11.07,
#   'Country': 'RU',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Weinan',
#   'Lat': 34.5,
#   'Lng': 109.51,
#   'Max Temp': 84,
#   'Humidity': 83,
#   'Cloudiness': 58,
#   'Wind Speed': 8.95,
#   'Country': 'CN',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Gawler',
#   'Lat': -34.6,
#   'Lng': 138.73,
#   'Max Temp': 46,
#   'Humidity': 77,
#   'Cloudiness': 10,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Mae Sai',
#   'Lat': 20.43,
#   'Lng': 99.88,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 3.36,
#   'Country': 'TH',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Magnor',
#   'Lat': 59.95,
#   'Lng': 12.2,
#   'Max Temp': 55.4,
#   'Humidity': 66,
#   'Cloudiness': 5,
#   'Wind Speed': 6.93,
#   'Country': 'SE',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Chabahar',
#   'Lat': 25.29,
#   'Lng': 60.64,
#   'Max Temp': 87.8,
#   'Humidity': 79,
#   'Cloudiness': 94,
#   'Wind Speed': 5.14,
#   'Country': 'IR',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Vierzon',
#   'Lat': 47.21,
#   'Lng': 2.06,
#   'Max Temp': 71.6,
#   'Humidity': 68,
#   'Cloudiness': 35,
#   'Wind Speed': 3.56,
#   'Country': 'FR',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Millet',
#   'Lat': 53.1,
#   'Lng': -113.47,
#   'Max Temp': 59,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 12.75,
#   'Country': 'CA',
#   'Current Description': 'mist',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Benguela',
#   'Lat': -12.58,
#   'Lng': 13.41,
#   'Max Temp': 66.9,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 2.71,
#   'Country': 'AO',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Pascagoula',
#   'Lat': 30.37,
#   'Lng': -88.56,
#   'Max Temp': 86,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 5.77,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Raymond Terrace',
#   'Lat': -32.75,
#   'Lng': 151.75,
#   'Max Temp': 44.01,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'AU',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Iqaluit',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Max Temp': 44.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Banda Aceh',
#   'Lat': 5.56,
#   'Lng': 95.32,
#   'Max Temp': 79.81,
#   'Humidity': 64,
#   'Cloudiness': 66,
#   'Wind Speed': 4.59,
#   'Country': 'ID',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Thompson',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Max Temp': 77,
#   'Humidity': 36,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'CA',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Alofi',
#   'Lat': -19.06,
#   'Lng': -169.92,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'NU',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'San Andres',
#   'Lat': 12.58,
#   'Lng': -81.7,
#   'Max Temp': 86,
#   'Humidity': 79,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Country': 'CO',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 67.71,
#   'Humidity': 46,
#   'Cloudiness': 68,
#   'Wind Speed': 9.66,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Shimoda',
#   'Lat': 34.67,
#   'Lng': 138.95,
#   'Max Temp': 70,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'JP',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.32,
#   'Snow (Inches)': 0},
#  {'City': 'Northam',
#   'Lat': 51.03,
#   'Lng': -4.22,
#   'Max Temp': 60.01,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 15.99,
#   'Country': 'GB',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Diapaga',
#   'Lat': 12.07,
#   'Lng': 1.79,
#   'Max Temp': 84.58,
#   'Humidity': 61,
#   'Cloudiness': 37,
#   'Wind Speed': 6.26,
#   'Country': 'BF',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.51,
#   'Snow (Inches)': 0},
#  {'City': 'Pangai',
#   'Lat': -19.8,
#   'Lng': -174.35,
#   'Max Temp': 73.4,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Country': 'TO',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Torbay',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Max Temp': 63,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Country': 'CA',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Phan Thiet',
#   'Lat': 10.93,
#   'Lng': 108.1,
#   'Max Temp': 75.65,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.13,
#   'Country': 'VN',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Sao Felix Do Xingu',
#   'Lat': -6.64,
#   'Lng': -51.99,
#   'Max Temp': 82.09,
#   'Humidity': 59,
#   'Cloudiness': 59,
#   'Wind Speed': 1.7,
#   'Country': 'BR',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Bengkulu',
#   'Lat': -3.8,
#   'Lng': 102.27,
#   'Max Temp': 74.16,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 4.09,
#   'Country': 'ID',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.15,
#   'Snow (Inches)': 0},
#  {'City': 'Geraldton',
#   'Lat': -28.77,
#   'Lng': 114.6,
#   'Max Temp': 48.2,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 12.37,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Nyurba',
#   'Lat': 63.28,
#   'Lng': 118.33,
#   'Max Temp': 57.88,
#   'Humidity': 69,
#   'Cloudiness': 45,
#   'Wind Speed': 5.28,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Burns Lake',
#   'Lat': 54.23,
#   'Lng': -125.75,
#   'Max Temp': 66.76,
#   'Humidity': 38,
#   'Cloudiness': 91,
#   'Wind Speed': 6.82,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Belmonte',
#   'Lat': -15.86,
#   'Lng': -38.88,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'BR',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Isangel',
#   'Lat': -19.55,
#   'Lng': 169.27,
#   'Max Temp': 64.4,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'VU',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Provideniya',
#   'Lat': 64.38,
#   'Lng': -173.3,
#   'Max Temp': 44.6,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 4.47,
#   'Country': 'RU',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Dudinka',
#   'Lat': 69.41,
#   'Lng': 86.18,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 22.37,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Barabinsk',
#   'Lat': 55.36,
#   'Lng': 78.36,
#   'Max Temp': 64.22,
#   'Humidity': 93,
#   'Cloudiness': 67,
#   'Wind Speed': 7.92,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Quang Ngai',
#   'Lat': 15.12,
#   'Lng': 108.8,
#   'Max Temp': 76.6,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4.16,
#   'Country': 'VN',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Puerto Palomas',
#   'Lat': 31.77,
#   'Lng': -107.62,
#   'Max Temp': 101.3,
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 6.8,
#   'Country': 'MX',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Yenagoa',
#   'Lat': 4.92,
#   'Lng': 6.26,
#   'Max Temp': 75,
#   'Humidity': 94,
#   'Cloudiness': 97,
#   'Wind Speed': 2.84,
#   'Country': 'NG',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Marzuq',
#   'Lat': 14.4,
#   'Lng': 46.47,
#   'Max Temp': 84.6,
#   'Humidity': 33,
#   'Cloudiness': 82,
#   'Wind Speed': 2.55,
#   'Country': 'YE',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Foam Lake',
#   'Lat': 51.65,
#   'Lng': -103.53,
#   'Max Temp': 69.1,
#   'Humidity': 66,
#   'Cloudiness': 41,
#   'Wind Speed': 16.11,
#   'Country': 'CA',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Longyearbyen',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Max Temp': 44.6,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'SJ',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Margate',
#   'Lat': 51.38,
#   'Lng': 1.39,
#   'Max Temp': 64,
#   'Humidity': 95,
#   'Cloudiness': 93,
#   'Wind Speed': 1.99,
#   'Country': 'GB',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.38,
#   'Snow (Inches)': 0},
#  {'City': 'Dikson',
#   'Lat': 73.51,
#   'Lng': 80.55,
#   'Max Temp': 42.85,
#   'Humidity': 87,
#   'Cloudiness': 39,
#   'Wind Speed': 14.79,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Max Temp': 68,
#   'Humidity': 68,
#   'Cloudiness': 58,
#   'Wind Speed': 6.93,
#   'Country': 'RE',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Haines Junction',
#   'Lat': 60.75,
#   'Lng': -137.51,
#   'Max Temp': 63.09,
#   'Humidity': 32,
#   'Cloudiness': 40,
#   'Wind Speed': 5.59,
#   'Country': 'CA',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Erenhot',
#   'Lat': 43.65,
#   'Lng': 111.98,
#   'Max Temp': 74.35,
#   'Humidity': 47,
#   'Cloudiness': 100,
#   'Wind Speed': 12.08,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Coquimbo',
#   'Lat': -29.95,
#   'Lng': -71.34,
#   'Max Temp': 59,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Country': 'CL',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Porto Tolle',
#   'Lat': 44.95,
#   'Lng': 12.32,
#   'Max Temp': 73,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 5.23,
#   'Country': 'IT',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Mount Isa',
#   'Lat': -20.73,
#   'Lng': 139.5,
#   'Max Temp': 48.2,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 14.5,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Ballina',
#   'Lat': -28.87,
#   'Lng': 153.57,
#   'Max Temp': 54,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Nsanje',
#   'Lat': -16.92,
#   'Lng': 35.26,
#   'Max Temp': 68.38,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 3.53,
#   'Country': 'MW',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Bulungu',
#   'Lat': -4.55,
#   'Lng': 18.6,
#   'Max Temp': 77.34,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 0.85,
#   'Country': 'CD',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Mayor Pablo Lagerenza',
#   'Lat': -19.93,
#   'Lng': -60.77,
#   'Max Temp': 57.09,
#   'Humidity': 63,
#   'Cloudiness': 98,
#   'Wind Speed': 5.01,
#   'Country': 'PY',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Loandjili',
#   'Lat': -4.76,
#   'Lng': 11.86,
#   'Max Temp': 73.4,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'CG',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Shetpe',
#   'Lat': 44.17,
#   'Lng': 52.12,
#   'Max Temp': 82.89,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'KZ',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Kalmar',
#   'Lat': 56.66,
#   'Lng': 16.36,
#   'Max Temp': 57,
#   'Humidity': 71,
#   'Cloudiness': 67,
#   'Wind Speed': 9.17,
#   'Country': 'SE',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Rio Real',
#   'Lat': -11.48,
#   'Lng': -37.93,
#   'Max Temp': 70.52,
#   'Humidity': 94,
#   'Cloudiness': 48,
#   'Wind Speed': 5.7,
#   'Country': 'BR',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.22,
#   'Snow (Inches)': 0},
#  {'City': 'Murchison',
#   'Lat': -41.8,
#   'Lng': 172.33,
#   'Max Temp': 35.26,
#   'Humidity': 80,
#   'Cloudiness': 4,
#   'Wind Speed': 1.59,
#   'Country': 'NZ',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Kupiskis',
#   'Lat': 55.83,
#   'Lng': 24.97,
#   'Max Temp': 47.79,
#   'Humidity': 92,
#   'Cloudiness': 31,
#   'Wind Speed': 5.82,
#   'Country': 'LT',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.66,
#   'Lng': -17.92,
#   'Max Temp': 81,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'ES',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Zhanakorgan',
#   'Lat': 43.91,
#   'Lng': 67.25,
#   'Max Temp': 78.46,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 6.98,
#   'Country': 'KZ',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Saint George',
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Max Temp': 100.99,
#   'Humidity': 6,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Cedar Falls',
#   'Lat': 42.53,
#   'Lng': -92.45,
#   'Max Temp': 95,
#   'Humidity': 47,
#   'Cloudiness': 20,
#   'Wind Speed': 12.75,
#   'Country': 'US',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Kon Tum',
#   'Lat': 14.35,
#   'Lng': 108,
#   'Max Temp': 69.48,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 0.74,
#   'Country': 'VN',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Sorkjosen',
#   'Lat': 69.8,
#   'Lng': 20.93,
#   'Max Temp': 48.6,
#   'Humidity': 76,
#   'Cloudiness': 7,
#   'Wind Speed': 1.97,
#   'Country': 'NO',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Tucson',
#   'Lat': 32.22,
#   'Lng': -110.93,
#   'Max Temp': 104,
#   'Humidity': 18,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Baoding',
#   'Lat': 38.85,
#   'Lng': 115.49,
#   'Max Temp': 70,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 6.87,
#   'Country': 'CN',
#   'Current Description': 'moderate rain',
#   'Rain (Inches)': 1.74,
#   'Snow (Inches)': 0},
#  {'City': 'Kingsville',
#   'Lat': 27.52,
#   'Lng': -97.86,
#   'Max Temp': 98.6,
#   'Humidity': 53,
#   'Cloudiness': 40,
#   'Wind Speed': 18.34,
#   'Country': 'US',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Cidreira',
#   'Lat': -30.18,
#   'Lng': -50.21,
#   'Max Temp': 55.92,
#   'Humidity': 87,
#   'Cloudiness': 87,
#   'Wind Speed': 22.7,
#   'Country': 'BR',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.16,
#   'Snow (Inches)': 0},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Max Temp': 84.69,
#   'Humidity': 69,
#   'Cloudiness': 14,
#   'Wind Speed': 4.85,
#   'Country': 'MV',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Celestun',
#   'Lat': 20.87,
#   'Lng': -90.4,
#   'Max Temp': 88.79,
#   'Humidity': 62,
#   'Cloudiness': 1,
#   'Wind Speed': 15.03,
#   'Country': 'MX',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Max Temp': 59,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Country': 'ZA',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Ayan',
#   'Lat': 56.45,
#   'Lng': 138.17,
#   'Max Temp': 50.32,
#   'Humidity': 87,
#   'Cloudiness': 4,
#   'Wind Speed': 4.68,
#   'Country': 'RU',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.49,
#   'Lng': 50.81,
#   'Max Temp': 79.95,
#   'Humidity': 73,
#   'Cloudiness': 18,
#   'Wind Speed': 27.96,
#   'Country': 'SO',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Aykhal',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': 53.6,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Mikuni',
#   'Lat': 36.22,
#   'Lng': 136.15,
#   'Max Temp': 71.6,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 1.12,
#   'Country': 'JP',
#   'Current Description': 'light intensity shower rain',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Mato Verde',
#   'Lat': -15.4,
#   'Lng': -42.87,
#   'Max Temp': 78.78,
#   'Humidity': 37,
#   'Cloudiness': 10,
#   'Wind Speed': 1.23,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Namibe',
#   'Lat': -15.2,
#   'Lng': 12.15,
#   'Max Temp': 65.8,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 2.39,
#   'Country': 'AO',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Gull Lake',
#   'Lat': 50.1,
#   'Lng': -108.48,
#   'Max Temp': 57.2,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 28.86,
#   'Country': 'CA',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Inhambane',
#   'Lat': -23.86,
#   'Lng': 35.38,
#   'Max Temp': 68,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Country': 'MZ',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Birao',
#   'Lat': 10.28,
#   'Lng': 22.79,
#   'Max Temp': 74.5,
#   'Humidity': 86,
#   'Cloudiness': 85,
#   'Wind Speed': 6.15,
#   'Country': 'CF',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.94,
#   'Snow (Inches)': 0},
#  {'City': 'Lavrentiya',
#   'Lat': 65.58,
#   'Lng': -171,
#   'Max Temp': 47.77,
#   'Humidity': 81,
#   'Cloudiness': 18,
#   'Wind Speed': 5.19,
#   'Country': 'RU',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Upernavik',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Max Temp': 42.85,
#   'Humidity': 69,
#   'Cloudiness': 34,
#   'Wind Speed': 10.67,
#   'Country': 'GL',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Bilibino',
#   'Lat': 68.05,
#   'Lng': 166.44,
#   'Max Temp': 63.14,
#   'Humidity': 52,
#   'Cloudiness': 80,
#   'Wind Speed': 2.89,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Eslov',
#   'Lat': 55.84,
#   'Lng': 13.3,
#   'Max Temp': 57,
#   'Humidity': 87,
#   'Cloudiness': 3,
#   'Wind Speed': 9.17,
#   'Country': 'SE',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Aklavik',
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Max Temp': 50,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'CA',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Bantry',
#   'Lat': 51.68,
#   'Lng': -9.45,
#   'Max Temp': 59,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'IE',
#   'Current Description': 'light intensity drizzle',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Audru',
#   'Lat': 58.41,
#   'Lng': 24.37,
#   'Max Temp': 55,
#   'Humidity': 80,
#   'Cloudiness': 2,
#   'Wind Speed': 10,
#   'Country': 'EE',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Mareeba',
#   'Lat': -17,
#   'Lng': 145.43,
#   'Max Temp': 69.8,
#   'Humidity': 77,
#   'Cloudiness': 56,
#   'Wind Speed': 10.29,
#   'Country': 'AU',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Avera',
#   'Lat': 33.19,
#   'Lng': -82.53,
#   'Max Temp': 86,
# ...
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Yeppoon',
#   'Lat': -23.13,
#   'Lng': 150.73,
#   'Max Temp': 59,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'AU',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Hokitika',
#   'Lat': -42.72,
#   'Lng': 170.97,
#   'Max Temp': 39.9,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'NZ',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Port Hardy',
#   'Lat': 50.7,
#   'Lng': -127.42,
#   'Max Temp': 59,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Cap Malheureux',
#   'Lat': -19.98,
#   'Lng': 57.61,
#   'Max Temp': 68,
#   'Humidity': 72,
#   'Cloudiness': 9,
#   'Wind Speed': 4,
#   'Country': 'MU',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Kamaishi',
#   'Lat': 39.27,
#   'Lng': 141.88,
#   'Max Temp': 69.64,
#   'Humidity': 81,
#   'Cloudiness': 96,
#   'Wind Speed': 4.41,
#   'Country': 'JP',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Zeya',
#   'Lat': 53.75,
#   'Lng': 127.27,
#   'Max Temp': 60.85,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 3.8,
#   'Country': 'RU',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Boende',
#   'Lat': -0.22,
#   'Lng': 20.87,
#   'Max Temp': 78.24,
#   'Humidity': 64,
#   'Cloudiness': 45,
#   'Wind Speed': 0.81,
#   'Country': 'CD',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Boa Vista',
#   'Lat': 2.82,
#   'Lng': -60.67,
#   'Max Temp': 91.4,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 12.75,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Gouyave',
#   'Lat': 12.16,
#   'Lng': -61.73,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 20.8,
#   'Country': 'GD',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Mamontovo',
#   'Lat': 52.71,
#   'Lng': 81.62,
#   'Max Temp': 59.85,
#   'Humidity': 91,
#   'Cloudiness': 32,
#   'Wind Speed': 6.2,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Fort Dodge',
#   'Lat': 42.5,
#   'Lng': -94.17,
#   'Max Temp': 93.2,
#   'Humidity': 52,
#   'Cloudiness': 20,
#   'Wind Speed': 10.29,
#   'Country': 'US',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Luxor',
#   'Lat': 25.7,
#   'Lng': 32.64,
#   'Max Temp': 93.2,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'EG',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 46.13,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 2.84,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Hailar',
#   'Lat': 49.2,
#   'Lng': 119.7,
#   'Max Temp': 66.67,
#   'Humidity': 60,
#   'Cloudiness': 89,
#   'Wind Speed': 11.63,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Flinders',
#   'Lat': -34.58,
#   'Lng': 150.86,
#   'Max Temp': 45,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Country': 'AU',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Brae',
#   'Lat': 60.4,
#   'Lng': -1.35,
#   'Max Temp': 51.8,
#   'Humidity': 81,
#   'Cloudiness': 11,
#   'Wind Speed': 9.17,
#   'Country': 'GB',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Santo Antonio Do Ica',
#   'Lat': -3.1,
#   'Lng': -67.94,
#   'Max Temp': 83.86,
#   'Humidity': 71,
#   'Cloudiness': 82,
#   'Wind Speed': 2.46,
#   'Country': 'BR',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.18,
#   'Snow (Inches)': 0},
#  {'City': 'Rize',
#   'Lat': 40.9,
#   'Lng': 40.89,
#   'Max Temp': 50.99,
#   'Humidity': 100,
#   'Cloudiness': 26,
#   'Wind Speed': 0.63,
#   'Country': 'TR',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Vieques',
#   'Lat': 18.43,
#   'Lng': -65.83,
#   'Max Temp': 89.6,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'PR',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Wawa',
#   'Lat': 9.9,
#   'Lng': 4.42,
#   'Max Temp': 78.15,
#   'Humidity': 81,
#   'Cloudiness': 53,
#   'Wind Speed': 7.67,
#   'Country': 'NG',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Okha',
#   'Lat': 53.57,
#   'Lng': 142.95,
#   'Max Temp': 50.76,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 9.53,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Saint-Georges',
#   'Lat': 12.06,
#   'Lng': -61.75,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 20.8,
#   'Country': 'GD',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Pitimbu',
#   'Lat': -7.47,
#   'Lng': -34.81,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'BR',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Superior',
#   'Lat': 46.72,
#   'Lng': -92.1,
#   'Max Temp': 86,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Ngerengere',
#   'Lat': -6.75,
#   'Lng': 38.12,
#   'Max Temp': 75.2,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 3.4,
#   'Country': 'TZ',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Rezekne',
#   'Lat': 56.5,
#   'Lng': 27.32,
#   'Max Temp': 52.14,
#   'Humidity': 94,
#   'Cloudiness': 96,
#   'Wind Speed': 5.95,
#   'Country': 'LV',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.13,
#   'Snow (Inches)': 0},
#  {'City': 'Banes',
#   'Lat': 20.96,
#   'Lng': -75.72,
#   'Max Temp': 93.2,
#   'Humidity': 52,
#   'Cloudiness': 40,
#   'Wind Speed': 10.29,
#   'Country': 'CU',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Pilar',
#   'Lat': -9.6,
#   'Lng': -35.96,
#   'Max Temp': 77,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Country': 'BR',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Ketchikan',
#   'Lat': 55.34,
#   'Lng': -131.65,
#   'Max Temp': 60.8,
#   'Humidity': 77,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'El Alto',
#   'Lat': -4.27,
#   'Lng': -81.21,
#   'Max Temp': 75.2,
#   'Humidity': 69,
#   'Cloudiness': 65,
#   'Wind Speed': 18.34,
#   'Country': 'PE',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Nemuro',
#   'Lat': 43.32,
#   'Lng': 145.57,
#   'Max Temp': 59.61,
#   'Humidity': 96,
#   'Cloudiness': 10,
#   'Wind Speed': 2.53,
#   'Country': 'JP',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Bonavista',
#   'Lat': 48.65,
#   'Lng': -53.11,
#   'Max Temp': 54,
#   'Humidity': 86,
#   'Cloudiness': 0,
#   'Wind Speed': 4,
#   'Country': 'CA',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Portarlington',
#   'Lat': 53.16,
#   'Lng': -7.19,
#   'Max Temp': 60.01,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.1,
#   'Country': 'IE',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.87,
#   'Snow (Inches)': 0},
#  {'City': 'Sinazongwe',
#   'Lat': -17.26,
#   'Lng': 27.46,
#   'Max Temp': 66.87,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 2.44,
#   'Country': 'ZM',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Khuzhir',
#   'Lat': 53.19,
#   'Lng': 107.34,
#   'Max Temp': 55.02,
#   'Humidity': 85,
#   'Cloudiness': 94,
#   'Wind Speed': 6.62,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Safford',
#   'Lat': 32.83,
#   'Lng': -109.71,
#   'Max Temp': 104,
#   'Humidity': 15,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Ladushkin',
#   'Lat': 54.57,
#   'Lng': 20.17,
#   'Max Temp': 53.6,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 8.95,
#   'Country': 'RU',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Coutances',
#   'Lat': 49.05,
#   'Lng': -1.43,
#   'Max Temp': 60.01,
#   'Humidity': 100,
#   'Cloudiness': 41,
#   'Wind Speed': 14.99,
#   'Country': 'FR',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Pundaguitan',
#   'Lat': 6.37,
#   'Lng': 126.17,
#   'Max Temp': 82.99,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 5.68,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Awjilah',
#   'Lat': 29.11,
#   'Lng': 21.29,
#   'Max Temp': 78.04,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 16.53,
#   'Country': 'LY',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Berlevag',
#   'Lat': 70.86,
#   'Lng': 29.09,
#   'Max Temp': 46.4,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'NO',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Zyryanka',
#   'Lat': 65.75,
#   'Lng': 150.85,
#   'Max Temp': 55.29,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 7.87,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Launceston',
#   'Lat': -41.45,
#   'Lng': 147.17,
#   'Max Temp': 43,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 1.63,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Bilma',
#   'Lat': 18.69,
#   'Lng': 12.92,
#   'Max Temp': 92.86,
#   'Humidity': 27,
#   'Cloudiness': 93,
#   'Wind Speed': 7.07,
#   'Country': 'NE',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Matehuala',
#   'Lat': 23.65,
#   'Lng': -100.65,
#   'Max Temp': 87.22,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 11.52,
#   'Country': 'MX',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Brookhaven',
#   'Lat': 31.58,
#   'Lng': -90.44,
#   'Max Temp': 79,
#   'Humidity': 94,
#   'Cloudiness': 97,
#   'Wind Speed': 6.58,
#   'Country': 'US',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Batticaloa',
#   'Lat': 7.71,
#   'Lng': 81.69,
#   'Max Temp': 81.1,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 6.93,
#   'Country': 'LK',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Rochegda',
#   'Lat': 62.8,
#   'Lng': 43.25,
#   'Max Temp': 65.68,
#   'Humidity': 96,
#   'Cloudiness': 63,
#   'Wind Speed': 3.69,
#   'Country': 'RU',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.39,
#   'Snow (Inches)': 0},
#  {'City': 'Timmins',
#   'Lat': 48.47,
#   'Lng': -81.33,
#   'Max Temp': 86,
#   'Humidity': 40,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Current Description': 'scattered clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Balagunan',
#   'Lat': 7.49,
#   'Lng': 125.52,
#   'Max Temp': 73.69,
#   'Humidity': 84,
#   'Cloudiness': 99,
#   'Wind Speed': 2.48,
#   'Country': 'PH',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Dobsice',
#   'Lat': 48.85,
#   'Lng': 16.08,
#   'Max Temp': 60.01,
#   'Humidity': 88,
#   'Cloudiness': 97,
#   'Wind Speed': 2.24,
#   'Country': 'CZ',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.19,
#   'Snow (Inches)': 0},
#  {'City': 'Katobu',
#   'Lat': -4.94,
#   'Lng': 122.53,
#   'Max Temp': 73.96,
#   'Humidity': 92,
#   'Cloudiness': 78,
#   'Wind Speed': 5.48,
#   'Country': 'ID',
#   'Current Description': 'broken clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Nauta',
#   'Lat': -4.51,
#   'Lng': -73.58,
#   'Max Temp': 82.74,
#   'Humidity': 79,
#   'Cloudiness': 81,
#   'Wind Speed': 1.9,
#   'Country': 'PE',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.29,
#   'Snow (Inches)': 0},
#  {'City': 'Cape Canaveral',
#   'Lat': 28.41,
#   'Lng': -80.6,
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Boulder City',
#   'Lat': 35.98,
#   'Lng': -114.83,
#   'Max Temp': 100.99,
#   'Humidity': 6,
#   'Cloudiness': 1,
#   'Wind Speed': 6.93,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Mendi',
#   'Lat': -6.18,
#   'Lng': 143.65,
#   'Max Temp': 51.69,
#   'Humidity': 97,
#   'Cloudiness': 12,
#   'Wind Speed': 3.18,
#   'Country': 'PG',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Galle',
#   'Lat': 6.04,
#   'Lng': 80.22,
#   'Max Temp': 80.74,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 11.16,
#   'Country': 'LK',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.22,
#   'Snow (Inches)': 0},
#  {'City': 'Khandbari',
#   'Lat': 27.37,
#   'Lng': 87.2,
#   'Max Temp': 75.88,
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 0.89,
#   'Country': 'NP',
#   'Current Description': 'light rain',
#   'Rain (Inches)': 0.94,
#   'Snow (Inches)': 0},
#  {'City': 'Chapais',
#   'Lat': 49.78,
#   'Lng': -74.85,
#   'Max Temp': 77,
#   'Humidity': 57,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'CA',
#   'Current Description': 'moderate rain',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Ndola',
#   'Lat': -12.96,
#   'Lng': 28.64,
#   'Max Temp': 56.19,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 4.83,
#   'Country': 'ZM',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Fethiye',
#   'Lat': 36.62,
#   'Lng': 29.12,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'TR',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Berndorf',
#   'Lat': 47.95,
#   'Lng': 16.11,
#   'Max Temp': 66.99,
#   'Humidity': 64,
#   'Cloudiness': 19,
#   'Wind Speed': 7,
#   'Country': 'AT',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Nantucket',
#   'Lat': 41.28,
#   'Lng': -70.1,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 1,
#   'Wind Speed': 14.99,
#   'Country': 'US',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Halifax',
#   'Lat': 44.65,
#   'Lng': -63.57,
#   'Max Temp': 62.01,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 13.87,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Kysyl-Syr',
#   'Lat': 63.9,
#   'Lng': 122.76,
#   'Max Temp': 58.62,
#   'Humidity': 62,
#   'Cloudiness': 12,
#   'Wind Speed': 4.85,
#   'Country': 'RU',
#   'Current Description': 'few clouds',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0},
#  {'City': 'Okakarara',
#   'Lat': -20.58,
#   'Lng': 17.43,
#   'Max Temp': 51.15,
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 6.44,
#   'Country': 'NA',
#   'Current Description': 'clear sky',
#   'Rain (Inches)': 0,
#   'Snow (Inches)': 0}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Tiruchchendur   8.48   78.12     81.25        71         100       12.66
# 1      Yellowknife  62.46 -114.35     64.40        45          40        5.82
# 2          College  64.86 -147.80     57.99        76          90        2.42
# 3         Bulawayo -20.15   28.58     55.13        62          48       14.74
# 4          Ushuaia -54.80  -68.30     41.00        75          40        8.05
# ..             ...    ...     ...       ...       ...         ...         ...
# 555       Berndorf  47.95   16.11     66.99        64          19        7.00
# 556      Nantucket  41.28  -70.10     71.60        83           1       14.99
# 557        Halifax  44.65  -63.57     62.01        87          90       13.87
# 558      Kysyl-Syr  63.90  122.76     58.62        62          12        4.85
# 559      Okakarara -20.58   17.43     51.15        39           0        6.44
#
#     Country Current Description  Rain (Inches)  Snow (Inches)
# 0        IN       moderate rain            1.2              0
# 1        CA    scattered clouds            0.0              0
# 2        US     overcast clouds            0.0              0
# 3        ZW    scattered clouds            0.0              0
# 4        AR    scattered clouds            0.0              0
# ..      ...                 ...            ...            ...
# 555      AT          few clouds            0.0              0
# 556      US           clear sky            0.0              0
# 557      CA     overcast clouds            0.0              0
# 558      RU          few clouds            0.0              0
# 559      NA           clear sky            0.0              0
#
# [560 rows x 11 columns]

# %%
#Creating new column order
#City, Country, Date, Lat, Lng, Max Temp, Humidity, Cloudiness, and Wind Speed,
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed", "Current Description", "Rain (Inches)", "Snow (Inches)"]

# %%
city_data_df.round({'Rain (Inches)':1})
# Out:
#               City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Tiruchchendur   8.48   78.12     81.25        71         100       12.66
# 1      Yellowknife  62.46 -114.35     64.40        45          40        5.82
# 2          College  64.86 -147.80     57.99        76          90        2.42
# 3         Bulawayo -20.15   28.58     55.13        62          48       14.74
# 4          Ushuaia -54.80  -68.30     41.00        75          40        8.05
# ..             ...    ...     ...       ...       ...         ...         ...
# 555       Berndorf  47.95   16.11     66.99        64          19        7.00
# 556      Nantucket  41.28  -70.10     71.60        83           1       14.99
# 557        Halifax  44.65  -63.57     62.01        87          90       13.87
# 558      Kysyl-Syr  63.90  122.76     58.62        62          12        4.85
# 559      Okakarara -20.58   17.43     51.15        39           0        6.44
#
#     Country Current Description  Rain (Inches)  Snow (Inches)
# 0        IN       moderate rain            1.2              0
# 1        CA    scattered clouds            0.0              0
# 2        US     overcast clouds            0.0              0
# 3        ZW    scattered clouds            0.0              0
# 4        AR    scattered clouds            0.0              0
# ..      ...                 ...            ...            ...
# 555      AT          few clouds            0.0              0
# 556      US           clear sky            0.0              0
# 557      CA     overcast clouds            0.0              0
# 558      RU          few clouds            0.0              0
# 559      NA           clear sky            0.0              0
#
# [560 rows x 11 columns]

# %%
city_data_df = city_data_df[new_column_order]

# %%
city_data_df
# Out:
#               City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Tiruchchendur      IN   8.48   78.12     81.25        71         100
# 1      Yellowknife      CA  62.46 -114.35     64.40        45          40
# 2          College      US  64.86 -147.80     57.99        76          90
# 3         Bulawayo      ZW -20.15   28.58     55.13        62          48
# 4          Ushuaia      AR -54.80  -68.30     41.00        75          40
# ..             ...     ...    ...     ...       ...       ...         ...
# 555       Berndorf      AT  47.95   16.11     66.99        64          19
# 556      Nantucket      US  41.28  -70.10     71.60        83           1
# 557        Halifax      CA  44.65  -63.57     62.01        87          90
# 558      Kysyl-Syr      RU  63.90  122.76     58.62        62          12
# 559      Okakarara      NA -20.58   17.43     51.15        39           0
#
#      Wind Speed Current Description  Rain (Inches)  Snow (Inches)
# 0         12.66       moderate rain            1.2              0
# 1          5.82    scattered clouds            0.0              0
# 2          2.42     overcast clouds            0.0              0
# 3         14.74    scattered clouds            0.0              0
# 4          8.05    scattered clouds            0.0              0
# ..          ...                 ...            ...            ...
# 555        7.00          few clouds            0.0              0
# 556       14.99           clear sky            0.0              0
# 557       13.87     overcast clouds            0.0              0
# 558        4.85          few clouds            0.0              0
# 559        6.44           clear sky            0.0              0
#
# [560 rows x 11 columns]

# %%
#Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
elif rain_input == "yes" and snow_input == "no":
    preferred1_cities_df = preferred_cities_df.loc[(city_data_df["Rain (Inches)"] > 0) & \
                                          (city_data_df["Snow (Inches)"]) == 0]
elif rain_input == "no" and snow_input == "no":
    preferred1_cities_df = preferred_cities_df.loc[(city_data_df["Rain (Inches)"] == 0) & \
                                          (city_data_df["Snow (Inches)"]) == 0]  
elif rain_input == "no" and snow_input == "yes":
    preferred1_cities_df = preferred_cities_df.loc[(city_data_df["Rain (Inches)"] > 0) & \
                                          (city_data_df["Snow (Inches)"]) == 0]
else:
    print("Input correct value.")
